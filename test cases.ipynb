# %%
import re
def rep(old):
    new='{% static \''+old+'\' %}'
    return  str(new)

def re_str(address,new_str,pattern=r'''href="([^"]*)"'''):
    with open(address,'r') as file:
        text = file.read()
        extracted_list=re.findall(pattern,text)
        print(extracted_list[0:3])
        new_list =[]
        for i in extracted_list:
            result = i.replace(i,rep(i))
            new_list.append(result)
        print(new_list[0:3])
        
    # file.seek()
        # file.writelines(extracted_list)

re_str(r'C:\Users\admin\Project\Main_project_SS\templates\base_test.html','a')
# Out:
# ['images/favicon.ico', 'images/apple-touch-icon.png', 'css/bootstrap.min.css']
# ["{% static 'images/favicon.ico' %}", "{% static 'images/apple-touch-icon.png' %}", "{% static 'css/bootstrap.min.css' %}"]

# %%
re_str('base.html',re_obj,'{% static '' %}')

# %%
with open(r'C:\Users\admin\Project\Main_project_SS\templates\base.html','r') as file1:
    data = file1.read()
print(data)
# Out:
# {% load static %}
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Freshshop - Ecommerce Bootstrap 4 HTML Template</title>
#     <meta name="keywords" content="">
#     <meta name="description" content="">
#     <meta name="author" content="">
#
#     <!-- Site Icons -->
#     <link rel="shortcut icon" href="{% static 'images/favicon.ico' %}" type="image/x-icon">
#     <link rel="apple-touch-icon" href="{% static 'images/apple-touch-icon.png' %}">
#
#     <!-- Bootstrap CSS -->
#     <link rel="stylesheet" href="{% static 'css/bootstrap.min.css' %}">
#     <!-- Site CSS -->
#     <link rel="stylesheet" href="{% static 'css/style.css' %}">
#     <!-- Responsive CSS -->
#     <link rel="stylesheet" href="{% static 'css/responsive.css' %}">
#     <!-- Custom CSS -->
# ...

# %%
a="""<link rel="shortcut icon" href="images/favicon.ico" type="image/x-icon">"""
print(a.replace('images/favicon.ico',"{% static 'images/favicon.ico' %}"))
# Out:
#   <link rel="shortcut icon" href="{% static 'images/favicon.ico' %}" type="image/x-icon">

# %%
pattern = '''href="([^"]*)"'''
re.findall(pattern,a)
# Out:
# ['images/favicon.ico']

# %%
import re
def rep(old):
    old=str(old)
    new='href="{% static \''+old[6:-1]+'\' %}"'
    return  str(new)

def re_str(address,pattern=r'''href="([^"]*)"'''):
    with open(address,'r+') as file:
        text = file.read()
        new_text=''
        count=0
        extracted_re_iterable=re.finditer(pattern,text)
        previous_end=0
        for i in extracted_re_iterable:
            count+=1
            # temp_from=text[i.start():i.end()]
            temp_to=rep(i.group())
            new_text=new_text+text[previous_end:i.start()]+temp_to
            # text= text[i.end()-2:]
            previous_end=i.end()
            # print(temp_from,temp_to)
            # text=text.replace(temp_from,temp_to)
            # new_list.append(result)
        # print(new_list[0:3])
    # file.seek()
        # file.writelines(extracted_list)
        new_text=new_text+text[previous_end:]
        file.seek(0)
        file.write(new_text)
    return new_text
result = re_str(r'C:\Users\admin\Project\Main_project_SS\templates\base_test.html')
print(result)













import re
def rep(old):
    old=str(old)
    new='href="{% static \''+old[6:-1]+'\' %}"'
    return  str(new)

def re_str(address,pattern=r'''href="([^"]*)"'''):
    with open(address,'r+') as file:
        text = file.read()
        new_text=''
        count=0
        extracted_re_iterable=re.finditer(pattern,text)
        previous_end=0
        for i in extracted_re_iterable:
            count+=1
            temp_to=rep(i.group())
            new_text=new_text+text[previous_end:i.start()]+temp_to
            previous_end=i.end()
        new_text=new_text+text[previous_end:]
        file.seek(0)
        file.write(new_text)
    return new_text













import os
def list_files_with_paths(folder_path):
    """
    List all files in the given folder and its subfolders, along with their full paths.

    Parameters:
    folder_path (str): The path to the folder.

    Returns:
    list: A list of tuples where each tuple contains the file name and its full path.
    """
    files_with_paths = []
    
    # Walk through the directory
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            full_path = os.path.join(root, file)
            files_with_paths.append((file, full_path))
    
    return files_with_paths

# Example usage:
folder_path = r'C:\Users\admin\Project\Main_project_SS\templates'
files = list_files_with_paths(folder_path)
for file_name, full_path in files:
    print(f"File: {file_name}, Path: {full_path}")
    re_str(full_path)

# %%
import re
def rep(old):
    old=str(old)
    new='src="{% static \''+old[5:-1]+'\' %}"'
    return  str(new)

def re_str(address,pattern=r'''src="([^"]*)"'''):
    with open(address,'r+') as file:
        text = file.read()
        new_text=''
        count=0
        extracted_re_iterable=re.finditer(pattern,text)
        previous_end=0
        for i in extracted_re_iterable:
            count+=1
            temp_to=rep(i.group())
            new_text=new_text+text[previous_end:i.start()]+temp_to
            previous_end=i.end()
        new_text=new_text+text[previous_end:]
        file.seek(0)
        file.write(new_text)
    return new_text

# %%
re_str(r'C:\Users\admin\Downloads\theme wegon\acuas-1.0.0\index.html')
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n    <head>\n        <meta charset="utf-8">\n        <title>Acuas - Drinking Water Website Template</title>\n        <meta content="width=device-width, initial-scale=1.0" name="viewport">\n        <meta content="" name="keywords">\n        <meta content="" name="description">\n\n        <!-- Google Web Fonts -->\n        <link rel="preconnect" href="https://fonts.googleapis.com">\n        <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\n        <link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wdth,wght@0,75..100,300..800;1,75..100,300..800&family=Playfair+Display:ital,wght@0,400..900;1,400..900&display=swap" rel="stylesheet"> \n\n        <!-- Icon Font Stylesheet -->\n        <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.15.4/css/all.css"/>\n        <link href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.4.1/font/bootstrap-icons.css" rel="stylesheet">\n\n        <!-- Libraries Style
# ...

# %%
import re
def rep(old):
    old=str(old)
    new='href="{% static \''+old[6:-1]+'\' %}"'
    return  str(new)

def href_replace(address,pattern=r'''a href="([^"]*)"'''):
    with open(address,'r+') as file:
        text = file.read()
        new_text=''
        count=0
        extracted_re_iterable=re.finditer(pattern,text)
        previous_end=0
        for i in extracted_re_iterable:
            count+=1
            temp_to=rep(i.group())
            new_text=new_text+text[previous_end:i.start()]+temp_to
            previous_end=i.end()
        new_text=new_text+text[previous_end:]
        file.seek(0)
        file.write(new_text)
    return new_text

# %%
href_replace(r"C:\Users\admin\Downloads\theme wegon\acuas-1.0.0\copy.html")
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n\n    <head>\n        <meta charset="utf-8">\n        <title>Acuas - Drinking Water Website Template</title>\n        <meta content="width=device-width, initial-scale=1.0" name="viewport">\n        <meta content="" name="keywords">\n        <meta content="" name="description">\n\n        <!-- Google Web Fonts -->\n        <link rel="preconnect" href="{% static \'{% static \'{% static \'{% static \'https://fonts.googleapis.com\' %}\' %}\' %}\' %}">\n        <link rel="preconnect" href="{% static \'{% static \'{% static \'{% static \'https://fonts.gstatic.com\' %}\' %}\' %}\' %}" crossorigin>\n        <link href="{% static \'{% static \'{% static \'{% static \'https://fonts.googleapis.com/css2?family=Open+Sans:ital,wdth,wght@0,75..100,300..800;1,75..100,300..800&family=Playfair+Display:ital,wght@0,400..900;1,400..900&display=swap\' %}\' %}\' %}\' %}" rel="stylesheet"> \n\n        <!-- Icon Font Stylesheet -->\n        <link rel="stylesheet" href="{% 
# ...

# %%
def list_files_with_paths(folder_path):
    """
    List all files in the given folder and its subfolders, along with their full paths.

    Parameters:
    folder_path (str): The path to the folder.

    Returns:
    list: A list of tuples where each tuple contains the file name and its full path.
    """
    files_with_paths = []
    
    # Walk through the directory
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            full_path = os.path.join(root, file)
            files_with_paths.append((file, full_path))
    
    return files_with_paths

# %%
list_files_with_paths(r"C:\Users\admin\Project\Main_project_SS\templates")
# Out:
# [('about.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\about.html'),
#  ('cart.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\cart.html'),
#  ('checkout.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\checkout.html'),
#  ('contact-us.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\contact-us.html'),
#  ('db.sqlite3',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\db.sqlite3'),
#  ('gallery.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\gallery.html'),
#  ('index.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\index.html'),
#  ('my-account.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\my-account.html'),
#  ('shop-detail.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\shop-detail.html'),
#  ('shop.html',
#   'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\shop.html'),
#  ('wishlist.html',
# ...

# %%
re_str(r'C:\\Users\\admin\\Project\\Main_project_SS\\templates\\wishlist.html')
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<!-- Basic -->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <!-- Mobile Metas -->\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n\n    <!-- Site Metas -->\n    <title>ThewayShop - Ecommerce Bootstrap 4 HTML Template</title>\n    <meta name="keywords" content="">\n    <meta name="description" content="">\n    <meta name="author" content="">\n\n    <!-- Site Icons -->\n    <link rel="shortcut icon" href="{% static \'images/favicon.ico\' %}" type="image/x-icon">\n    <link rel="apple-touch-icon" href="{% static \'images/apple-touch-icon.png\' %}">\n\n    <!-- Bootstrap CSS -->\n    <link rel="stylesheet" href="{% static \'css/bootstrap.min.css\' %}">\n    <!-- Site CSS -->\n    <link rel="stylesheet" href="{% static \'css/style.css\' %}">\n    <!-- Responsive CSS -->\n    <link rel="stylesheet" href="{% static \'css/responsive.css\' %}">\n    <!-- Custom CSS -->\n  
# ...
